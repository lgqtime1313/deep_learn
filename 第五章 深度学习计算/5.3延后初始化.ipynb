# %%
# 延后初始化 LazyLinear(output)
import torch
from torch import nn

# %%
net = nn.Sequential(
    nn.LazyLinear(24),
    nn.ReLU(),
    nn.Linear(24, 10),
    )

# %%
print(net)
# Out:
# Sequential(
#   (0): LazyLinear(in_features=0, out_features=24, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=24, out_features=10, bias=True)
# )

# %%
Y = torch.rand(2,4)
net(Y)
# Out:
# tensor([[-0.0359,  0.0765,  0.1174, -0.2993, -0.1630,  0.1978,  0.1199, -0.1095,
#          -0.1222,  0.0567],
#         [ 0.0509,  0.1004,  0.1953, -0.3147, -0.0395,  0.1255,  0.1977, -0.1747,
#          -0.2051,  0.1105]], grad_fn=<AddmmBackward0>)

# %%
print(net)
# Out:
# Sequential(
#   (0): Linear(in_features=4, out_features=24, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=24, out_features=10, bias=True)
# )
